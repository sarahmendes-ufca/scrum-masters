# %% [markdown]
# <a href="https://colab.research.google.com/github/sudo-invers/yolo-edge-api/blob/main/yolo_edge_apiipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Verificar drive do cuda

# %%
import torch

print("CUDA disponível:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA disponível: True
# GPU: Tesla T4
